# %%
import tweepy
import csv
import pandas as pd
import os
# !pip install wget
import wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=6e0c81a1064a5a7a1c87cb970411a1d02e9c7b96daf86799fdca4c2bfd082232
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# ...

# %%
# !pip install pip
import pip
package ='tweepy'
pip.main(['install',package])
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# 0

# %%
consumer_key = "TcM1ZCaf49vzQaFSbbyrlC4N7"
consumer_secret = "Ovqer3vNt73gW4bm8Hj4V7veHNi20XMmRcdYHmEfOwUIuNlgqi"
access_key = "1591050207160049668-NqmPbSI8j7esRjJoukP9dM1cxsBWjJ"
access_secret = "9VXkWvaJDhyhf6RVdXONlFzLOYTEM7ufXCffbT0YW0Any"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
outtweets = [] 

for tweet in tweepy.Cursor(api.search,q="#job",count = 100, lang="en", since="2022-10-10").items():
  outtweets.append([tweet.id_str,tweet.created_at,tweet.text.encode("utf-8"), tweet.user.location, tweet.user.statuses_count])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-6a39f6d1f0eb> in <module>
#       4 outtweets = []
#       5
# ----> 6 for tweet in tweepy.Cursor(api.search,q="#job",count = 100, lang="en", since="2022-10-10").items():
# ...

# %%
outtweets
# Out:
# [['1591615489796612096',
#   datetime.datetime(2022, 11, 13, 2, 14, 38),
#   b"The Myers-Briggs Company has a career opportunity. Join us as we enrich people's understanding of themselves and ot\xe2\x80\xa6 https://t.co/RZ6WvW6EBN",
#   'San Antonio, TX',
#   2655],
#  ['1591615278169067520',
#   datetime.datetime(2022, 11, 13, 2, 13, 47),
#   b'Palo Alto Networks is looking for: Technical Support Engineer, Cortex - Japan\nhttps://t.co/Pq8XEijoQF #job',
#   'North Andover, MA',
#   8607],
#  ['1591615109293608961',
#   datetime.datetime(2022, 11, 13, 2, 13, 7),
#   b'RT @DiedreMoire: Controls Engineer - Production Line Machinery - Wichita, KS #DiedreMoire #JobSearch #JobHunt #JobOpening #Hiring #Job #Job\xe2\x80\xa6',
#   'Everywhere',
#   472193],
#  ['1591615087466500096',
#   datetime.datetime(2022, 11, 13, 2, 13, 2),
#   b'Controls Engineer - Production Line Machinery - Wichita, KS #DiedreMoire #JobSearch #JobHunt #JobOpening #Hiring\xe2\x80\xa6 https://t.co/JwyrzTPEtg',
# ...

# %%
tweetdf = pd.DataFrame(outtweets,columns = ["ID","Created_at","Text","Location","Statuses"])
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/outputtweet.csv'
with open(path, 'w') as f:
  tweetdf.to_csv(f)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
